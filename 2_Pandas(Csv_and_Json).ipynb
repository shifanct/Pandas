# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df=pd.read_csv("/content/data - data.csv")

# %%
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.shape
# Out:
# (169, 4)

# %%
df.shape[1]
# Out:
# 4

# %%
df.shape[0]
# Out:
# 169

# %%
print(f"shape of dataframe : rows= {df.shape[0]} colums={df.shape[1]}")
# Out:
# shape of dataframe : rows= 169 colums=4

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head(9)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.tail(10)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df["Calories"]
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       300.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       269.0
# 10      329.3
# 11      250.7
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17        NaN
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27        NaN
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...

# %%
df["Duration"]
# Out:
# 0       60
# 1       60
# 2       60
# 3       45
# 4       45
# 5       60
# 6       60
# 7       45
# 8       30
# 9       60
# 10      60
# 11      60
# 12      60
# 13      60
# 14      60
# 15      60
# 16      60
# 17      45
# 18      60
# 19      45
# 20      60
# 21      45
# 22      60
# 23      45
# 24      60
# 25      60
# 26      60
# 27      60
# 28      60
# 29      60
# 30      60
# 31      45
# 32      60
# 33      60
# 34      60
# 35      60
# 36      60
# 37      60
# 38      60
# 39      45
# 40      45
# 41      60
# 42      60
# 43      60
# 44      60
# 45      60
# 46      60
# 47      45
# 48      45
# 49      60
# 50      60
# 51      80
# 52      60
# 53      60
# 54      30
# 55      60
# 56      60
# 57      45
# 58      20
# 59      45
# 60     210
# 61     160
# 62     160
# 63      45
# 64      20
# 65     180
# 66     150
# 67     150
# 68      20
# 69     300
# 70     150
# 71      60
# 72      90
# 73     150
# 74      45
# 75      90
# ...

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# ## Another Data

# %%
df1=pd.read_csv("/content/company info - Sheet1.csv")

# %%
print(df1)
# Out:
#     emp_id      emp_name             job role  salary  experience
# 0     1001         edwin              teacher   30000           2
# 1     1002         david              trainer   35000           3
# 2     1003        shifan               farmer   23000           4
# 3     1004         insaf              plumber   35000           2
# 4     1005         shijo               barber   10000           1
# 5     1006        adarsh               driver   23000           5
# 6     1007         madhu               helper   60000           3
# 7     1008         najad              cleaner   70000           2
# 8     1009          ajin                 cook   80000           4
# 9     1010          lijo            developer   67000           2
# 10    1011          sijo           accountant   45000           3
# 11    1012          biju              manager   68400           1
# 12    1013         baiju             chairman   87850           3
# ...

# %%
print(df1.to_string())
# Out:
#     emp_id      emp_name             job role  salary  experience
# 0     1001         edwin              teacher   30000           2
# 1     1002         david              trainer   35000           3
# 2     1003        shifan               farmer   23000           4
# 3     1004         insaf              plumber   35000           2
# 4     1005         shijo               barber   10000           1
# 5     1006        adarsh               driver   23000           5
# 6     1007         madhu               helper   60000           3
# 7     1008         najad              cleaner   70000           2
# 8     1009          ajin                 cook   80000           4
# 9     1010          lijo            developer   67000           2
# 10    1011          sijo           accountant   45000           3
# 11    1012          biju              manager   68400           1
# 12    1013         baiju             chairman   87850           3
# ...

# %%
print(df1.head())
# Out:
#    emp_id emp_name job role  salary  experience
# 0    1001    edwin  teacher   30000           2
# 1    1002    david  trainer   35000           3
# 2    1003   shifan   farmer   23000           4
# 3    1004    insaf  plumber   35000           2
# 4    1005    shijo   barber   10000           1

# %%
print(df1.head(9))
# Out:
#    emp_id emp_name job role  salary  experience
# 0    1001    edwin  teacher   30000           2
# 1    1002    david  trainer   35000           3
# 2    1003   shifan   farmer   23000           4
# 3    1004    insaf  plumber   35000           2
# 4    1005    shijo   barber   10000           1
# 5    1006   adarsh   driver   23000           5
# 6    1007    madhu   helper   60000           3
# 7    1008    najad  cleaner   70000           2
# 8    1009     ajin     cook   80000           4

# %%
print(df1.tail())
# Out:
#     emp_id      emp_name   job role  salary  experience
# 45    1046        kannus      staff   50000           1
# 46    1047         sunny    cashier   90000          11
# 47    1048          miya  collector  849900          10
# 48    1049  danidaniyels   minister   90900           8
# 49    1050       thulasi   cleaning   15000           4

# %%
print(df1.tail(6))
# Out:
#     emp_id      emp_name   job role  salary  experience
# 44    1045          noha         ca  577700           4
# 45    1046        kannus      staff   50000           1
# 46    1047         sunny    cashier   90000          11
# 47    1048          miya  collector  849900          10
# 48    1049  danidaniyels   minister   90900           8
# 49    1050       thulasi   cleaning   15000           4

# %%
print(df1.describe())
# Out:
#            emp_id         salary  experience
# count    50.00000      50.000000   50.000000
# mean   1025.50000  128801.600000    3.340000
# std      14.57738  224617.455937    2.086008
# min    1001.00000    5000.000000    1.000000
# 25%    1013.25000   31250.000000    2.000000
# 50%    1025.50000   67000.000000    3.000000
# 75%    1037.75000   86845.000000    4.000000
# max    1050.00000  970000.000000   11.000000

# %%
df1["emp_id"]
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
# 5     1006
# 6     1007
# 7     1008
# 8     1009
# 9     1010
# 10    1011
# 11    1012
# 12    1013
# 13    1014
# 14    1015
# 15    1016
# 16    1017
# 17    1018
# 18    1019
# 19    1020
# 20    1021
# 21    1022
# 22    1023
# 23    1024
# 24    1025
# 25    1026
# 26    1027
# 27    1028
# 28    1029
# 29    1030
# 30    1031
# 31    1032
# 32    1033
# 33    1034
# 34    1035
# 35    1036
# 36    1037
# 37    1038
# 38    1039
# 39    1040
# 40    1041
# 41    1042
# 42    1043
# 43    1044
# 44    1045
# 45    1046
# 46    1047
# 47    1048
# 48    1049
# 49    1050
# Name: emp_id, dtype: int64

# %%
df1.columns
# Out:
# Index(['emp_id', 'emp_name', 'job role', 'salary', 'experience'], dtype='object')

# %%
print(df1.loc[0])
# Out:
# emp_id           1001
# emp_name        edwin
# job role      teacher
# salary          30000
# experience          2
# Name: 0, dtype: object

# %%
print(df1.loc[[1,2]])
# Out:
#    emp_id emp_name job role  salary  experience
# 1    1002    david  trainer   35000           3
# 2    1003   shifan   farmer   23000           4

# %%
print(df1.loc[2:4])
# Out:
#    emp_id emp_name job role  salary  experience
# 2    1003   shifan   farmer   23000           4
# 3    1004    insaf  plumber   35000           2
# 4    1005    shijo   barber   10000           1

# %%
print(df1.loc[3,"salary"])
# Out:
# 35000

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_name    50 non-null     object
#  2   job role    50 non-null     object
#  3   salary      50 non-null     int64
#  4   experience  50 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None

# %%
df1.tail(4)
# Out:
#     emp_id      emp_name   job role  salary  experience
# 46    1047         sunny    cashier   90000          11
# 47    1048          miya  collector  849900          10
# 48    1049  danidaniyels   minister   90900           8
# 49    1050       thulasi   cleaning   15000           4

# %%
df2=pd.read_csv("/content/company info - Sheet1 (1).csv")

# %%
df2
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0     1001         edwin              teacher   30000.0         2.0
# 1     1002         david              trainer       NaN         3.0
# 2     1003        shifan               farmer   23000.0         4.0
# 3     1004         insaf              plumber   35000.0         2.0
# 4     1005         shijo               barber   10000.0         1.0
# 5     1006        adarsh               driver   23000.0         5.0
# 6     1007         madhu               helper   60000.0         3.0
# 7     1008           NaN              cleaner   70000.0         NaN
# 8     1009          ajin                 cook   80000.0         4.0
# 9     1010          lijo            developer   67000.0         2.0
# 10    1011          sijo           accountant   45000.0         3.0
# 11    1012          biju              manager   68400.0         1.0
# 12    1013         baiju             chairman   87850.0         3.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_name    47 non-null     object
#  2   job role    48 non-null     object
#  3   salary      46 non-null     float64
#  4   experience  49 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df3=pd.read_csv("/content/company info - Sheet1 (1).csv")
df3
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0     1001         edwin              teacher   30000.0         2.0
# 1     1002         david              trainer       NaN         3.0
# 2     1003        shifan               farmer   23000.0         4.0
# 3     1004         insaf              plumber   35000.0         2.0
# 4     1005         shijo               barber   10000.0         1.0
# 5     1006        adarsh               driver   23000.0         5.0
# 6     1007         madhu               helper   60000.0         3.0
# 7     1008           NaN              cleaner   70000.0         NaN
# 8     1009          ajin                 cook   80000.0         4.0
# 9     1010          lijo            developer   67000.0         2.0
# 10    1011          sijo           accountant   45000.0         3.0
# 11    1012          biju              manager   68400.0         1.0
# 12    1013         baiju             chairman   87850.0         3.0
# ...

# %%
pd.options.display.max_rows=30 #default is 60

# %%
print(pd.options.display.max_rows)
# Out:
# 30

# %%
df3
# Out:
#     emp_id      emp_name   job role    salary  experience
# 0     1001         edwin    teacher   30000.0         2.0
# 1     1002         david    trainer       NaN         3.0
# 2     1003        shifan     farmer   23000.0         4.0
# 3     1004         insaf    plumber   35000.0         2.0
# 4     1005         shijo     barber   10000.0         1.0
# ..     ...           ...        ...       ...         ...
# 45    1046        kannus      staff   50000.0         1.0
# 46    1047         sunny    cashier   90000.0        11.0
# 47    1048          miya  collector  849900.0        10.0
# 48    1049  danidaniyels   minister   90900.0         8.0
# 49    1050       thulasi   cleaning   15000.0         4.0
#
# [50 rows x 5 columns]

# %%
pd.options.display.max_rows = 100

# %%
print(df3)
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0     1001         edwin              teacher   30000.0         2.0
# 1     1002         david              trainer       NaN         3.0
# 2     1003        shifan               farmer   23000.0         4.0
# 3     1004         insaf              plumber   35000.0         2.0
# 4     1005         shijo               barber   10000.0         1.0
# 5     1006        adarsh               driver   23000.0         5.0
# 6     1007         madhu               helper   60000.0         3.0
# 7     1008           NaN              cleaner   70000.0         NaN
# 8     1009          ajin                 cook   80000.0         4.0
# 9     1010          lijo            developer   67000.0         2.0
# 10    1011          sijo           accountant   45000.0         3.0
# 11    1012          biju              manager   68400.0         1.0
# 12    1013         baiju             chairman   87850.0         3.0
# ...

# %% [markdown]
# # Read Json files

# %%
import pandas as pd

# %%
df2=pd.read_json("/content/iris.json")

# %%
print(df2.to_string())
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth     species
# 0            5.1         3.5          1.4         0.2      setosa
# 1            4.9         3.0          1.4         0.2      setosa
# 2            4.7         3.2          1.3         0.2      setosa
# 3            4.6         3.1          1.5         0.2      setosa
# 4            5.0         3.6          1.4         0.2      setosa
# 5            5.4         3.9          1.7         0.4      setosa
# 6            4.6         3.4          1.4         0.3      setosa
# 7            5.0         3.4          1.5         0.2      setosa
# 8            4.4         2.9          1.4         0.2      setosa
# 9            4.9         3.1          1.5         0.1      setosa
# 10           5.4         3.7          1.5         0.2      setosa
# 11           4.8         3.4          1.6         0.2      setosa
# 12           4.8         3.0          1.4         0.1      setosa
# ...

# %% [markdown]
# # Dictionary as JSON

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  }
  }
df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse
# 0        60    110
# 1        60    117
# 2        60    103
# 3        45    109
# 4        45    117
# 5        60    102
