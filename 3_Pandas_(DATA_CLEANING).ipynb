# %%
import pandas as pd

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # Drop Null values

# %%
df=pd.read_csv("/content/data - data.csv")

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.shape
# Out:
# (169, 4)

# %%
# drop null values in df
new_df=df.dropna()

# %%
print(new_df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
new_df.shape
# Out:
# (164, 4)

# %%
new_df["Maxpulse"]
# Out:
# 0      130
# 1      145
# 2      135
# 3      175
# 4      148
#       ...
# 164    140
# 165    145
# 166    145
# 167    150
# 168    150
# Name: Maxpulse, Length: 164, dtype: int64

# %%
# Drop null values with changing the original dataset
df.dropna(inplace=True)

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %% [markdown]
# # Replace Null values

# %%
df1=pd.read_csv("/content/data - data.csv")
print(df1.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df2=df1.fillna(50)

# %%
print(df2.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112      50.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# change the original dataset
df1.fillna(100,inplace=True)
print(df1.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     100.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# fill the null value only in one column
df1["Calories"].fillna(150,inplace=True)
print(df1.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     100.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# # Replacing null values using meam, median, mod

# %%
x=pd.read_csv("/content/data - data.csv")

# %%
print(x.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
mean=x["Calories"].mean()
x["Calories"].fillna(mean,inplace=True)
print(x.to_string())
print(mean)
# Out:
#      Duration  Pulse  Maxpulse     Calories
# 0          60    110       130   409.100000
# 1          60    117       145   479.000000
# 2          60    103       135   340.000000
# 3          45    109       175   282.400000
# 4          45    117       148   406.000000
# 5          60    102       127   300.000000
# 6          60    110       136   374.000000
# 7          45    104       134   253.300000
# 8          30    109       133   195.100000
# 9          60     98       124   269.000000
# 10         60    103       147   329.300000
# 11         60    100       120   250.700000
# 12         60    106       128   345.300000
# 13         60    104       132   379.300000
# 14         60     98       123   275.000000
# 15         60     98       120   215.200000
# 16         60    100       120   300.000000
# 17         45     90       112   375.790244
# 18         60    103       123   323.000000
# 19         45     97       125   243.000000
# ...

# %% [markdown]
# ## replace null values in company info using Mean,Median,Mode

# %%
import pandas as pd

# %%
x=pd.read_csv("/content/company info - Sheet1 (2).csv")
print(x.to_string())
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0   1001.0         edwin              teacher   30000.0         2.0
# 1   1002.0         david              trainer       NaN         3.0
# 2   1003.0        shifan               farmer   23000.0         NaN
# 3   1004.0         insaf              plumber   35000.0         2.0
# 4   1005.0           NaN               barber       NaN         1.0
# 5   1006.0        adarsh               driver       NaN         5.0
# 6   1007.0         madhu               helper   60000.0         3.0
# 7      NaN           NaN              cleaner   70000.0         NaN
# 8   1009.0          ajin                 cook   80000.0         4.0
# 9   1010.0          lijo            developer   67000.0         2.0
# 10  1011.0          sijo           accountant   45000.0         3.0
# 11  1012.0          biju              manager   68400.0         1.0
# 12  1013.0         baiju             chairman   87850.0         3.0
# ...

# %%
mean=x["experience"].mean()
x["experience"].fillna(mean,inplace=True)
print(mean)
# Out:
# 3.347826086956522

# %%
print(x.to_string())
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0   1001.0         edwin              teacher   30000.0    2.000000
# 1   1002.0         david              trainer       NaN    3.000000
# 2   1003.0        shifan               farmer   23000.0    3.347826
# 3   1004.0         insaf              plumber   35000.0    2.000000
# 4   1005.0           NaN               barber       NaN    1.000000
# 5   1006.0        adarsh               driver       NaN    5.000000
# 6   1007.0         madhu               helper   60000.0    3.000000
# 7      NaN           NaN              cleaner   70000.0    3.347826
# 8   1009.0          ajin                 cook   80000.0    4.000000
# 9   1010.0          lijo            developer   67000.0    2.000000
# 10  1011.0          sijo           accountant   45000.0    3.000000
# 11  1012.0          biju              manager   68400.0    1.000000
# 12  1013.0         baiju             chairman   87850.0    3.000000
# ...

# %%
median=x["salary"].median()
print(median)
# Out:
# 67000.0

# %%
x["salary"].fillna(median,inplace=True)
print(x.to_string())
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0   1001.0         edwin              teacher   30000.0    2.000000
# 1   1002.0         david              trainer   67000.0    3.000000
# 2   1003.0        shifan               farmer   23000.0    3.347826
# 3   1004.0         insaf              plumber   35000.0    2.000000
# 4   1005.0           NaN               barber   67000.0    1.000000
# 5   1006.0        adarsh               driver   67000.0    5.000000
# 6   1007.0         madhu               helper   60000.0    3.000000
# 7      NaN           NaN              cleaner   70000.0    3.347826
# 8   1009.0          ajin                 cook   80000.0    4.000000
# 9   1010.0          lijo            developer   67000.0    2.000000
# 10  1011.0          sijo           accountant   45000.0    3.000000
# 11  1012.0          biju              manager   68400.0    1.000000
# 12  1013.0         baiju             chairman   87850.0    3.000000
# ...

# %%
mode=x["emp_id"].mode()[0]
print(mode)
# Out:
# 1001.0

# %%
x["emp_id"].fillna(mode,inplace=True)
print(x.to_string())
# Out:
#     emp_id      emp_name             job role    salary  experience
# 0   1001.0         edwin              teacher   30000.0    2.000000
# 1   1002.0         david              trainer   67000.0    3.000000
# 2   1003.0        shifan               farmer   23000.0    3.347826
# 3   1004.0         insaf              plumber   35000.0    2.000000
# 4   1005.0           NaN               barber   67000.0    1.000000
# 5   1006.0        adarsh               driver   67000.0    5.000000
# 6   1007.0         madhu               helper   60000.0    3.000000
# 7   1001.0           NaN              cleaner   70000.0    3.347826
# 8   1009.0          ajin                 cook   80000.0    4.000000
# 9   1010.0          lijo            developer   67000.0    2.000000
# 10  1011.0          sijo           accountant   45000.0    3.000000
# 11  1012.0          biju              manager   68400.0    1.000000
# 12  1013.0         baiju             chairman   87850.0    3.000000
# ...

# %% [markdown]
# # FiLLNA WITH ANOTHR DATASET

# %%
import pandas as pd

# %%
df2=pd.read_csv("/content/company_data_with_nulls.csv")

# %%
print(df2.to_string())
# Out:
#      Column_1  Column_2  Column_3  Column_4  Column_5  Column_6
# 0       688.0     764.0     829.0     669.0       NaN     995.0
# 1       883.0       NaN       NaN     317.0     906.0       NaN
# 2         NaN     519.0     533.0       NaN     362.0     220.0
# 3       223.0       NaN     792.0       NaN     329.0     379.0
# 4       780.0       5.0     145.0     146.0     109.0     828.0
# 5         NaN     919.0     306.0     149.0     478.0       NaN
# 6       643.0     981.0     705.0       NaN     546.0     584.0
# 7       315.0     408.0       NaN       NaN       NaN     366.0
# 8       165.0     223.0     555.0     190.0     358.0     748.0
# 9         NaN     522.0     971.0     337.0     599.0     669.0
# 10      541.0       NaN       NaN     771.0       NaN     437.0
# 11        NaN     422.0     164.0     684.0     164.0       NaN
# 12       48.0     664.0    1000.0     444.0       NaN     793.0
# 13      804.0     983.0       NaN       NaN       NaN       NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column_1  285 non-null    float64
#  1   Column_2  278 non-null    float64
#  2   Column_3  291 non-null    float64
#  3   Column_4  277 non-null    float64
#  4   Column_5  266 non-null    float64
#  5   Column_6  283 non-null    float64
# dtypes: float64(6)
# memory usage: 18.9 KB

# %%
#mean=df2.mean()
#print(mean)
# Out:
# Column_1    489.361404
# Column_2    502.881295
# Column_3    472.323024
# Column_4    503.444043
# Column_5    489.646617
# Column_6    508.173145
# dtype: float64

# %%
#df2.fillna(mean,inplace=True)
#print(df2.to_string())

# %%
x=df2["Column_1"].mean()
print(x)
df2["Column_1"].fillna(mean,inplace=True)
print(df2["Column_1"].to_string())
# Out:
# 489.36140350877196
# 0      688.000000
# 1      883.000000
# 2      489.361404
# 3      223.000000
# 4      780.000000
# 5      489.361404
# 6      643.000000
# 7      315.000000
# 8      165.000000
# 9      489.361404
# 10     541.000000
# 11     489.361404
# 12      48.000000
# 13     804.000000
# 14     656.000000
# 15     489.361404
# 16     489.361404
# 17     489.361404
# 18     664.000000
# 19     691.000000
# 20     489.361404
# 21     965.000000
# 22     476.000000
# 23     951.000000
# 24     810.000000
# 25     874.000000
# 26     675.000000
# 27     489.361404
# 28     413.000000
# 29     489.361404
# 30     489.361404
# 31     489.361404
# 32     489.361404
# 33     403.000000
# 34     476.000000
# 35      50.000000
# 36     466.000000
# 37     962.000000
# 38     456.000000
# 39     489.361404
# 40     489.361404
# 41     489.361404
# 42     353.000000
# 43     489.361404
# 44     489.361404
# 45     244.000000
# 46     489.361404
# 47     727.000000
# ...

# %%
# replace colum_2 with median
med=df2["Column_2"].median()
print(med)
df2["Column_2"].fillna(med,inplace=True)
print(df2["Column_2"].to_string())
# Out:
# 502.88129496402877
# 0      764.000000
# 1      502.881295
# 2      519.000000
# 3      502.881295
# 4        5.000000
# 5      919.000000
# 6      981.000000
# 7      408.000000
# 8      223.000000
# 9      522.000000
# 10     502.881295
# 11     422.000000
# 12     664.000000
# 13     983.000000
# 14     502.881295
# 15     392.000000
# 16     502.881295
# 17     502.881295
# 18     283.000000
# 19     529.000000
# 20     502.881295
# 21     787.000000
# 22     563.000000
# 23     502.881295
# 24     776.000000
# 25     754.000000
# 26      77.000000
# 27     158.000000
# 28     502.881295
# 29     225.000000
# 30     502.881295
# 31     502.881295
# 32     861.000000
# 33     502.881295
# 34     917.000000
# 35     502.881295
# 36     502.881295
# 37     502.881295
# 38     202.000000
# 39     502.881295
# 40     502.881295
# 41      32.000000
# 42     516.000000
# 43     502.881295
# 44     533.000000
# 45     502.881295
# 46     940.000000
# 47     537.000000
# ...

# %%
# replace column_3 with mode
mod=df2["Column_3"].mode()
print(mod)
df2["Column_3"].fillna(mod,inplace=True)
print(df2["Column_3"].to_string())
# Out:
# 0    472.323024
# Name: Column_3, dtype: float64
# 0       829.000000
# 1       472.323024
# 2       533.000000
# 3       792.000000
# 4       145.000000
# 5       306.000000
# 6       705.000000
# 7       472.323024
# 8       555.000000
# 9       971.000000
# 10      472.323024
# 11      164.000000
# 12     1000.000000
# 13      472.323024
# 14       34.000000
# 15      197.000000
# 16      396.000000
# 17      341.000000
# 18      472.323024
# 19       17.000000
# 20      472.323024
# 21      472.323024
# 22      678.000000
# 23      115.000000
# 24       36.000000
# 25       56.000000
# 26      472.323024
# 27      384.000000
# 28      923.000000
# 29      283.000000
# 30      472.323024
# 31      738.000000
# 32      831.000000
# 33      472.323024
# 34      622.000000
# 35      438.000000
# 36       33.000000
# 37      548.000000
# 38      803.000000
# 39      863.000000
# 40      551.000000
# 41      356.000000
# 42       16.000000
# 43      446.000000
# 44      256.000000
# ...

# %%
their_mean=df2[["Column_4","Column_5","Column_6"]].mean()
print(their_mean)
# Out:
# Column_4    503.444043
# Column_5    489.646617
# Column_6    508.173145
# dtype: float64

# %%
df2[["Column_4","Column_5","Column_6"]].fillna(their_mean,inplace=True)
print(df2.to_string())
# Out:
#        Column_1    Column_2     Column_3    Column_4     Column_5    Column_6
# 0    688.000000  764.000000   829.000000  669.000000   489.646617  995.000000
# 1    883.000000  502.881295   472.323024  317.000000   906.000000  508.173145
# 2    489.361404  519.000000   533.000000  503.444043   362.000000  220.000000
# 3    223.000000  502.881295   792.000000  503.444043   329.000000  379.000000
# 4    780.000000    5.000000   145.000000  146.000000   109.000000  828.000000
# 5    489.361404  919.000000   306.000000  149.000000   478.000000  508.173145
# 6    643.000000  981.000000   705.000000  503.444043   546.000000  584.000000
# 7    315.000000  408.000000   472.323024  503.444043   489.646617  366.000000
# 8    165.000000  223.000000   555.000000  190.000000   358.000000  748.000000
# 9    489.361404  522.000000   971.000000  337.000000   599.000000  669.000000
# 10   541.000000  502.881295   472.323024  771.000000   489.646617  437.000000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column_1  400 non-null    float64
#  1   Column_2  400 non-null    float64
#  2   Column_3  400 non-null    float64
#  3   Column_4  400 non-null    float64
#  4   Column_5  400 non-null    float64
#  5   Column_6  400 non-null    float64
# dtypes: float64(6)
# memory usage: 18.9 KB

# %% [markdown]
# # cleaning Data in wrong format

# %% [markdown]
# # Fixing wrong format data

# %%
df=pd.DataFrame({
    "date":["2022-03-14","01-02-2023","2020-04-13","3.4.2018","2020 4 1"]

})
print(df)
# Out:
#          date
# 0  2022-03-14
# 1  01-02-2023
# 2  2020-04-13
# 3    3.4.2018
# 4    2020 4 1

# %%
df["date"]=pd.to_datetime(df["date"],format="mixed")
print(df)
# Out:
#         date
# 0 2022-03-14
# 1 2023-01-02
# 2 2020-04-13
# 3 2018-03-04
# 4 2020-04-01

# %% [markdown]
# #REmoving Wrong format Data

# %%
import pandas as pd

# %%
df1=pd.DataFrame({
    "date":["2022-03-14","01-02-2023","2020-04-13","","2020 4 1"]

})
print(df1)
# Out:
#          date
# 0  2022-03-14
# 1  01-02-2023
# 2  2020-04-13
# 3
# 4    2020 4 1

# %%
df1["date"]=pd.to_datetime(df1["date"],format="mixed")
print(df1)
# Out:
#         date
# 0 2022-03-14
# 1 2023-01-02
# 2 2020-04-13
# 3        NaT
# 4 2020-04-01

# %%
df1.dropna(subset=["date"],inplace=True)
print(df1)
#df1["date"].dropna(inplace=True)
# Out:
#         date
# 0 2022-03-14
# 1 2023-01-02
# 2 2020-04-13
# 4 2020-04-01

# %%
df1
# Out:
#         date
# 0 2022-03-14
# 1 2023-01-02
# 2 2020-04-13
# 4 2020-04-01

# %% [markdown]
# # wrong Data

# %% [markdown]
# ## Replacing wrong Data

# %%
data={
    "name":["vishunu","kiran","abi","snan","yscn","anand","sxmil"],
    "age":[17,18,160,19,19,18,22],
    "salary":[25000,18000,30000,300000,22000,32000,15000]
}
df=pd.DataFrame(data,index=["a","b","c","d","e","f","g"])
df
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi  160   30000
# d     snan   19  300000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   15000

# %%
df.loc["d","salary"]=30000
df.loc["c","age"]=16

# %%
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi   16   30000
# d     snan   19   30000
# e     yscn   19   22000
# f    anand   18   30000
# g    sxmil   22   15000

# %% [markdown]
# ## if the DataSET is very big we can use a for loop

# %%
# example for a for loo[p
x=[10,20,30,40,50,100,110,120]
y=100
for i in x:
  if i >= y:
    i=y
  print(i,end=" ")
# Out:
# 10 20 30 40 50 100 100 100

# %%
x=[10,20,30,40,50,100,110,120]
lst=[]
for i in x:
  if i>100:
    lst.append(100)
  else:
    lst.append(i)
print(lst)
# Out:
# [10, 20, 30, 40, 50, 100, 100, 100]

# %%
data={
    "name":["vishunu","kiran","abi","snan","yscn","anand","sxmil"],
    "age":[17,18,160,19,19,18,22],
    "salary":[25000,18000,30000,300000,22000,32000,15000]
}
df=pd.DataFrame(data,index=["a","b","c","d","e","f","g"])
df
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi  160   30000
# d     snan   19  300000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   15000

# %%
for i in df.index:
  print(i)
# Out:
# a
# b
# c
# d
# e
# f
# g

# %%
for i  in df.index:
  if df.loc[i,"salary"] > 50000:
    df.loc[i,"salary"] = 35000

# %%
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi  160   30000
# d     snan   19   35000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   15000

# %%
for x in df.index:
  if df.loc[x,"age"] > 25:
    df.loc[x,"age"] = 20
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi   20   30000
# d     snan   19   35000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   15000

# %%
df.loc["g","salary"]=50000
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   18000
# c      abi   20   30000
# d     snan   19   35000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   50000

# %%
for i in df.index:
  if df.loc[i,"salary"] <20000:
    df.loc[i,"salary"] = 45000
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   45000
# c      abi   20   30000
# d     snan   19   35000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   50000

# %%
for i in df.index:
  if df.loc[i,"age"] >= 20:
    df.loc[i,"salary"] = 50000
print(df)
# Out:
#       name  age  salary
# a  vishunu   17   25000
# b    kiran   18   45000
# c      abi   20   50000
# d     snan   19   35000
# e     yscn   19   22000
# f    anand   18   32000
# g    sxmil   22   50000

# %% [markdown]
# ## remove the wrong data

# %%
data={
    "name":["shifan","insaf","swalh","edwin","david"],
    "age":[18,19,20,17,21],
    "salary":[25000,30000,20000,34000,28000],
    "exp":[5,4,5,6,7]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  age  salary  exp
# 0  shifan   18   25000    5
# 1   insaf   19   30000    4
# 2   swalh   20   20000    5
# 3   edwin   17   34000    6
# 4   david   21   28000    7

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#     name  salary  exp
# 1  insaf   30000    4
# 2  swalh   20000    5
# 3  edwin   34000    6
# 4  david   28000    7

# %%
for x in df.index:
  if df.loc[x,"age"]>20:
    df.drop(x,inplace=True)
df
# Out:
#     name  age  salary  exp
# 1  insaf   19   30000    4
# 2  swalh   20   20000    5
# 3  edwin   17   34000    6

# %% [markdown]
# # duplicates

# %% [markdown]
# ## remove duplicates

# %%
import pandas as pd

# %%
dup=[[10,2,43],[11,5,15],[10,2,67],[10,2,43],[34,70,5],[23,45,32],[10,2,43]]
df=pd.DataFrame(dup)
print(df)
# Out:
#     0   1   2
# 0  10   2  43
# 1  11   5  15
# 2  10   2  67
# 3  10   2  43
# 4  34  70   5
# 5  23  45  32
# 6  10   2  43

# %%
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     0   1   2
# 0  10   2  43
# 1  11   5  15
# 2  10   2  67
# 4  34  70   5
# 5  23  45  32

# %%
data={
    "equipment":["fan","Ac","board","fan"],
    "price":[2500,36000,150000,2500],
    "quantity":[2,2,1,2]
}

xdf=pd.DataFrame(data)

# %%
print(xdf.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
xdf.drop_duplicates(inplace=True)
print(xdf)
# Out:
#   equipment   price  quantity
# 0       fan    2500         2
# 1        Ac   36000         2
# 2     board  150000         1
